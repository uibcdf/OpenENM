# %% [markdown]
# # Test GNM

# %%
import openenm as oenm

# %%
my_gnm = oenm.GaussianNetworkModel('1TCD', selection='atom_name=="CA"', cutoff='12 angstroms')
# Out:
# /home/diego/MyMachine/locals/miniconda3/envs/OpenENM@dprada_3.9/lib/python3.9/site-packages/molsysmt/item/mmtf_MMTFDecoder/to_molsysmt_Topology.py:32: UserWarning: The structure in the PDB has biological assemblies. There are geometrical transformations proposed in the structure. See the following issue in the source code repository: https://github.com/uibcdf/MolSysMT/issues/33
#   warnings.warn(warning_message)

# %%
my_gnm.atom_indices

# %%
my_gnm.cutoff

# %%
my_gnm.contacts

# %%
my_gnm.show_contact_map()

# %%
my_gnm.calculate_contacts(cutoff='7.5 angstroms')

# %%
my_gnm.show_contact_map()

# %%
my_gnm.correlation_matrix

# %%
my_gnm.b_factors_exp

# %%
my_gnm.b_factors

# %%
my_gnm.show_correlation_matrix()

# %%
my_gnm.show_best_cutoff()

# %%
my_gnm.scaling_factor

# %%
my_gnm.show_b_factors()
# Out:
# /home/diego/MyMachine/locals/miniconda3/envs/OpenENM@dprada_3.9/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1298: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)

# %%
my_gnm.show_dispersion_b_factors()
# Out:
# /home/diego/MyMachine/locals/miniconda3/envs/OpenENM@dprada_3.9/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1298: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)
